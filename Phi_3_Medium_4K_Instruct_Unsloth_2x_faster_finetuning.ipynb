# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth#installation-instructions---conda).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).
#
# We'll use the `Phi-3` format for conversational finetunes. We use the [Open Assistant dataset](https://huggingface.co/datasets/philschmid/guanaco-sharegpt-style) in ShareGPT style.

# %%
# %%capture
# # Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps xformers trl peft accelerate bitsandbytes

# %%
model_id = "unsloth/Phi-3-medium-4k-instruct"
dataset_id = "gretelai/synthetic_text_to_sql"

from dotenv import load_dotenv
import os
from huggingface_hub import login

output_dir = os.path.join(".", f"{model_id.split('/')[1]}-{dataset_id.split('/')[1]}-outputs")

# Load the .env file
load_dotenv()

# Get the token
token = os.getenv("HUGGINGFACE_TOKEN")
# token_write = os.getenv("HUGGINGFACE_TOKEN_WRITE")

login(
  token=token,
  add_to_git_credential=True
)

import wandb
os.environ["WANDB_PROJECT"] = f"{model_id.split('/')[1]}-{dataset_id.split('/')[1]}"
os.environ["WANDB_LOG_MODEL"] = "checkpoint"  # log all model checkpoints
# Set the WANDB_NOTEBOOK_NAME environment variable
os.environ["WANDB_NOTEBOOK_NAME"] = os.path.basename(os.getcwd())
# Out:
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /home/bizon/.cache/huggingface/token
# Login successful

# %% [markdown]
# * We support Llama, Mistral, Phi-3, Gemma, Yi, DeepSeek, Qwen, TinyLlama, Vicuna, Open Hermes etc
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * With [PR 26037](https://github.com/huggingface/transformers/pull/26037), we support downloading 4bit models **4x faster**! [Our repo](https://huggingface.co/unsloth) has Llama, Mistral 4bit models.
# * [**NEW**] We make Llama-3 15 trillion tokens **2x faster**! See our [Llama-3 notebook](https://colab.research.google.com/drive/135ced7oHytdxu3N2DNe1Z0kqjyYIkDXp?usp=sharing)

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/mistral-7b-v0.3-bnb-4bit",      # New Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/llama-3-8b-bnb-4bit",           # Llama-3 15 trillion tokens model 2x faster!
    "unsloth/llama-3-8b-Instruct-bnb-4bit",
    "unsloth/llama-3-70b-bnb-4bit",
    "unsloth/Phi-3-mini-4k-instruct",        # Phi-3 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",             # Gemma 2.2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_id,
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    token = token, # use one if using gated models like meta-llama/Llama-2-7b-hf
)

# %%
# show cuda devices
print(torch.cuda.device_count())

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the `Phi-3` format for conversation style finetunes. We use [Open Assistant conversations](https://huggingface.co/datasets/philschmid/guanaco-sharegpt-style) in ShareGPT style. Phi-3 renders multi turn conversations like below:
#
# ```
# <s><|user|>
# Hi!<|end|>
# <|assistant|>
# Hello! How are you?<|end|>
# <|user|>
# I'm doing great! And you?<|end|>
#
# ```
#
# **[NOTE]** To train only on completions (ignoring the user's input) read TRL's docs [here](https://huggingface.co/docs/trl/sft_trainer#train-on-completions-only).
#
# We use our `get_chat_template` function to get the correct chat template. We support `zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old` and our own optimized `unsloth` template.
#
# Note ShareGPT uses `{"from": "human", "value" : "Hi"}` and not `{"role": "user", "content" : "Hi"}`, so we use `mapping` to map it.
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing).

# %%
# Load the dataset
from datasets import load_dataset
dataset = load_dataset(dataset_id, split="train")

# Function to preprocess the dataset and create the conversation format
def preprocess_dataset(examples):
    conversations = []
    for sql_prompt, sql_context, sql in zip(examples["sql_prompt"], examples["sql_context"], examples["sql"]):
        # Making the user input more organic
        user_input = (
            f"I need a SQL query for the following request:\n"
            f"{sql_prompt}\n\n"
            f"Here is the context:\n"
            f"{sql_context}\n"
        )
        # Making the assistant output more professional yet organic
        assistant_output = (
            f"{sql}"
        )
        conversation = [{"from": "user", "value": user_input}, {"from": "assistant", "value": assistant_output}]
        conversations.append(conversation)

    return {"conversations": conversations}

# Apply the preprocessing to the dataset
dataset = dataset.map(preprocess_dataset, batched=True)

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "phi-3", # Supports zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, unsloth
    mapping = {"role" : "from", "content" : "value", "user" : "human", "assistant" : "gpt"}, # ShareGPT style
)


def formatting_prompts_func(examples):
    convos = examples["conversations"]
    texts = [tokenizer.apply_chat_template(convo, tokenize = False, add_generation_prompt = False) for convo in convos]
    return { "text" : texts, }
pass

# from datasets import load_dataset
# dataset = load_dataset("philschmid/guanaco-sharegpt-style", split = "train")
dataset = dataset.map(formatting_prompts_func, batched = True,)

# %% [markdown]
# Let's see how the `Phi-3` format works by printing the 5th element

# %%
print(dataset[5]["text"])

# %%
dataset[5]["conversations"]

# %%
print(dataset[5]["text"])

# %% [markdown]
# If you're looking to make your own chat template, that also is possible! You must use the Jinja templating regime. We provide our own stripped down version of the `Unsloth template` which we find to be more efficient, and leverages ChatML, Zephyr and Alpaca styles.
#
# More info on chat templates on [our wiki page!](https://github.com/unslothai/unsloth/wiki#chat-templates)

# %%
# unsloth_template = \
#     "{{ bos_token }}"\
#     "{{ 'You are a helpful assistant to the user\n' }}"\
#     "{% endif %}"\
#     "{% for message in messages %}"\
#         "{% if message['role'] == 'user' %}"\
#             "{{ '>>> User: ' + message['content'] + '\n' }}"\
#         "{% elif message['role'] == 'assistant' %}"\
#             "{{ '>>> Assistant: ' + message['content'] + eos_token + '\n' }}"\
#         "{% endif %}"\
#     "{% endfor %}"\
#     "{% if add_generation_prompt %}"\
#         "{{ '>>> Assistant: ' }}"\
#     "{% endif %}"
# unsloth_eos_token = "eos_token"

# if False:
#     tokenizer = get_chat_template(
#         tokenizer,
#         chat_template = (unsloth_template, unsloth_eos_token,), # You must provide a template and EOS token
#         mapping = {"role" : "from", "content" : "value", "user" : "human", "assistant" : "gpt"}, # ShareGPT style
#         map_eos_token = True, # Maps <|im_end|> to </s> instead
#     )

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
# from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        num_train_epochs=3,
        # max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = output_dir,
    ),
)

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")

# %%
# change tokenizer_utils to check for none and empty strings
    # # Check if tokenizer and training datasets have bad tokens
    # if_bad_first  = False
    # if_bad_second = False
    # # Check tokenizer's chat template for any untrained tokens
    # chat_template = getattr(tokenizer, "chat_template", None)
    # if chat_template is not None:
    #      # Filter out None and empty strings
    #     actual_bad_tokens = [token for token in actual_bad_tokens if token not in (None, '')]
    #     if_bad_first = any(x in chat_template for x in actual_bad_tokens)
    # pass

# %%
# trainer_stats = trainer.train()
# start from checkpoint
trainer_stats = trainer.train(resume_from_checkpoint = "Phi-3-medium-4k-instruct-synthetic_text_to_sql-outputs/checkpoint-33500")

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! Since we're using `Phi-3`, use `apply_chat_template` with `add_generation_prompt` set to `True` for inference.

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "phi-3", # Supports zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, unsloth
    mapping = {"role" : "from", "content" : "value", "user" : "human", "assistant" : "gpt"}, # ShareGPT style
)

FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"from": "human", "value": "Continue the fibonnaci sequence: 1, 1, 2, 3, 5, 8,"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

outputs = model.generate(input_ids = inputs, max_new_tokens = 64, use_cache = True)
tokenizer.batch_decode(outputs)

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"from": "human", "value": "Continue the fibonnaci sequence: 1, 1, 2, 3, 5, 8,"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(input_ids = inputs, streamer = text_streamer, max_new_tokens = 128, use_cache = True)

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
# load the model from the checkpoint
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# model id = latest checkpoint in the output directory
model_from_checkpoint = f"{output_dir}/checkpoint-37500"
hf_path = f"{model_id.split('/')[1]}-{dataset_id.split('/')[1]}-lora-3epochs"
lora_path = f"lora/{hf_path}"

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_from_checkpoint,
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = token, # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ==((====))==  Unsloth: Fast Mistral patching release 2024.5
#    \\   /|    GPU: NVIDIA GeForce RTX 4090. Max memory: 23.643 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.0. CUDA = 8.9. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. Xformers = 0.0.26.post1. FA = True.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Unsloth 2024.5 patched 40 layers with 40 QKV layers, 40 O layers and 40 MLP layers.

# %%
# model.save_pretrained("lora_model") # Local saving
model.save_pretrained(lora_path) # Local saving
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
model.push_to_hub(f"felixml/{hf_path}", token = token) # Online saving

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"from": "human", "value": "What is a famous tall tower in Paris?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(input_ids = inputs, streamer = text_streamer, max_new_tokens = 128, use_cache = True)

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoModelForPeftCausalLM
    from transformers import AutoTokenizer
    model = AutoModelForPeftCausalLM.from_pretrained(
        "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("lora_model")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
# if True: model.save_pretrained_gguf(f"{lora_path}-Q8_0", tokenizer,)
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q5_k_m GGUF
# if True: model.save_pretrained_gguf(f"{lora_path}-q5_k_m", tokenizer, quantization_method = "q5_k_m")
if True: model.push_to_hub_gguf(f"felixml/{hf_path}-q5_k_m", tokenizer, quantization_method = "q5_k_m", token = token)

# Save to q4_k_m GGUF
# if True: model.save_pretrained_gguf(f"{lora_path}-Q4_0", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")
# Out:
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 192.55 out of 251.37 RAM for saving.
# 100%|██████████| 40/40 [00:28<00:00,  1.41it/s]
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 5 minutes for Llama-7b...
# Done.
# Unsloth: Extending felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m/tokenizer.model with added_tokens.json.
# Originally tokenizer.model is of size (32000).
# But we need to extend to sentencepiece vocab size (32011).
# ==((====))==  Unsloth: Conversion from QLoRA to GGUF information
#    \\   /|    [0] Installing llama.cpp will take 3 minutes.
# O^O/ \_/ \    [1] Converting HF to GUUF 16bits will take 3 minutes.
# \        /    [2] Converting GGUF 16bits to q5_k_m will take 20 minutes.
#  "-____-"     In total, you will have to wait around 26 minutes.
#
# Unsloth: [0] Installing llama.cpp. This will take 3 minutes...
# Unsloth: [1] Converting model at felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m into f16 GGUF format.
# The output location will be ./felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m-unsloth.F16.gguf
# This will take 3 minutes...
# INFO:convert:Loading model file felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m/model-00001-of-00006.safetensors
# INFO:convert:Loading model file felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m/model-00001-of-00006.safetensors
# INFO:convert:Loading model file felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m/model-00002-of-00006.safetensors
# INFO:convert:Loading model file felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m/model-00003-of-00006.safetensors
# INFO:convert:Loading model file felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m/model-00004-of-00006.safetensors
# INFO:convert:Loading model file felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m/model-00005-of-00006.safetensors
# INFO:convert:Loading model file felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m/model-00006-of-00006.safetensors
# INFO:convert:model parameters count : 13960238080 (14B)
# INFO:convert:params = Params(n_vocab=32064, n_embd=5120, n_layer=40, n_ctx=4096, n_ff=17920, n_head=40, n_head_kv=10, n_experts=None, n_experts_used=None, f_norm_eps=1e-05, rope_scaling_type=None, f_rope_freq_base=10000.0, f_rope_scale=None, n_orig_ctx=None, rope_finetuned=None, ftype=<GGMLFileType.MostlyF16: 1>, path_model=PosixPath('felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m'))
# INFO:convert:Loaded vocab file PosixPath('felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m/tokenizer.model'), type 'spm'
# INFO:convert:Vocab info: <SentencePieceVocab with 32011 base tokens and 0 added tokens>
# INFO:convert:Special vocab info: <SpecialVocab with 0 merges, special tokens {'bos': 1, 'eos': 32000, 'unk': 0, 'pad': 32009}, add special tokens {'bos': False, 'eos': False}>
# INFO:convert:Writing felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m-unsloth.F16.gguf, format 1
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:gguf.vocab:Setting special token type bos to 1
# INFO:gguf.vocab:Setting special token type eos to 32000
# INFO:gguf.vocab:Setting special token type unk to 0
# INFO:gguf.vocab:Setting special token type pad to 32009
# INFO:gguf.vocab:Setting add_bos_token to False
# INFO:gguf.vocab:Setting add_eos_token to False
# INFO:gguf.vocab:Setting chat_template to {{ bos_token }}{% for message in messages %}{% if message['from'] == 'human' %}{{'<|user|>
# ' + message['value'] + '<|end|>
# '}}{% elif message['from'] == 'gpt' %}{{'<|assistant|>
# ' + message['value'] + '<|end|>
# '}}{% else %}{{'<|' + message['from'] + '|>
# ' + message['value'] + '<|end|>
# '}}{% endif %}{% endfor %}{% if add_generation_prompt %}{{ '<|assistant|>
# ' }}{% endif %}
# INFO:convert:[  1/363] Writing tensor token_embd.weight                      | size  32064 x   5120  | type F16  | T+   2
# INFO:convert:[  2/363] Writing tensor blk.0.attn_norm.weight                 | size   5120           | type F32  | T+   2
# INFO:convert:[  3/363] Writing tensor blk.0.ffn_down.weight                  | size   5120 x  17920  | type F16  | T+   2
# INFO:convert:[  4/363] Writing tensor blk.0.ffn_gate.weight                  | size  17920 x   5120  | type F16  | T+   3
# INFO:convert:[  5/363] Writing tensor blk.0.ffn_up.weight                    | size  17920 x   5120  | type F16  | T+   3
# INFO:convert:[  6/363] Writing tensor blk.0.ffn_norm.weight                  | size   5120           | type F32  | T+   3
# INFO:convert:[  7/363] Writing tensor blk.0.attn_k.weight                    | size   1280 x   5120  | type F16  | T+   3
# INFO:convert:[  8/363] Writing tensor blk.0.attn_output.weight               | size   5120 x   5120  | type F16  | T+   3
# INFO:convert:[  9/363] Writing tensor blk.0.attn_q.weight                    | size   5120 x   5120  | type F16  | T+   3
# INFO:convert:[ 10/363] Writing tensor blk.0.attn_v.weight                    | size   1280 x   5120  | type F16  | T+   3
# INFO:convert:[ 11/363] Writing tensor blk.1.attn_norm.weight                 | size   5120           | type F32  | T+   3
# INFO:convert:[ 12/363] Writing tensor blk.1.ffn_down.weight                  | size   5120 x  17920  | type F16  | T+   3
# INFO:convert:[ 13/363] Writing tensor blk.1.ffn_gate.weight                  | size  17920 x   5120  | type F16  | T+   3
# INFO:convert:[ 14/363] Writing tensor blk.1.ffn_up.weight                    | size  17920 x   5120  | type F16  | T+   3
# INFO:convert:[ 15/363] Writing tensor blk.1.ffn_norm.weight                  | size   5120           | type F32  | T+   3
# INFO:convert:[ 16/363] Writing tensor blk.1.attn_k.weight                    | size   1280 x   5120  | type F16  | T+   3
# INFO:convert:[ 17/363] Writing tensor blk.1.attn_output.weight               | size   5120 x   5120  | type F16  | T+   3
# INFO:convert:[ 18/363] Writing tensor blk.1.attn_q.weight                    | size   5120 x   5120  | type F16  | T+   3
# INFO:convert:[ 19/363] Writing tensor blk.1.attn_v.weight                    | size   1280 x   5120  | type F16  | T+   3
# INFO:convert:[ 20/363] Writing tensor blk.2.attn_norm.weight                 | size   5120           | type F32  | T+   4
# INFO:convert:[ 21/363] Writing tensor blk.2.ffn_down.weight                  | size   5120 x  17920  | type F16  | T+   4
# INFO:convert:[ 22/363] Writing tensor blk.2.ffn_gate.weight                  | size  17920 x   5120  | type F16  | T+   4
# INFO:convert:[ 23/363] Writing tensor blk.2.ffn_up.weight                    | size  17920 x   5120  | type F16  | T+   4
# INFO:convert:[ 24/363] Writing tensor blk.2.ffn_norm.weight                  | size   5120           | type F32  | T+   4
# INFO:convert:[ 25/363] Writing tensor blk.2.attn_k.weight                    | size   1280 x   5120  | type F16  | T+   4
# INFO:convert:[ 26/363] Writing tensor blk.2.attn_output.weight               | size   5120 x   5120  | type F16  | T+   4
# INFO:convert:[ 27/363] Writing tensor blk.2.attn_q.weight                    | size   5120 x   5120  | type F16  | T+   4
# INFO:convert:[ 28/363] Writing tensor blk.2.attn_v.weight                    | size   1280 x   5120  | type F16  | T+   4
# INFO:convert:[ 29/363] Writing tensor blk.3.attn_norm.weight                 | size   5120           | type F32  | T+   4
# INFO:convert:[ 30/363] Writing tensor blk.3.ffn_down.weight                  | size   5120 x  17920  | type F16  | T+   4
# INFO:convert:[ 31/363] Writing tensor blk.3.ffn_gate.weight                  | size  17920 x   5120  | type F16  | T+   4
# INFO:convert:[ 32/363] Writing tensor blk.3.ffn_up.weight                    | size  17920 x   5120  | type F16  | T+   4
# INFO:convert:[ 33/363] Writing tensor blk.3.ffn_norm.weight                  | size   5120           | type F32  | T+   4
# INFO:convert:[ 34/363] Writing tensor blk.3.attn_k.weight                    | size   1280 x   5120  | type F16  | T+   4
# INFO:convert:[ 35/363] Writing tensor blk.3.attn_output.weight               | size   5120 x   5120  | type F16  | T+   4
# INFO:convert:[ 36/363] Writing tensor blk.3.attn_q.weight                    | size   5120 x   5120  | type F16  | T+   5
# INFO:convert:[ 37/363] Writing tensor blk.3.attn_v.weight                    | size   1280 x   5120  | type F16  | T+   5
# INFO:convert:[ 38/363] Writing tensor blk.4.attn_norm.weight                 | size   5120           | type F32  | T+   5
# INFO:convert:[ 39/363] Writing tensor blk.4.ffn_down.weight                  | size   5120 x  17920  | type F16  | T+   5
# INFO:convert:[ 40/363] Writing tensor blk.4.ffn_gate.weight                  | size  17920 x   5120  | type F16  | T+   5
# INFO:convert:[ 41/363] Writing tensor blk.4.ffn_up.weight                    | size  17920 x   5120  | type F16  | T+   5
# INFO:convert:[ 42/363] Writing tensor blk.4.ffn_norm.weight                  | size   5120           | type F32  | T+   5
# INFO:convert:[ 43/363] Writing tensor blk.4.attn_k.weight                    | size   1280 x   5120  | type F16  | T+   5
# INFO:convert:[ 44/363] Writing tensor blk.4.attn_output.weight               | size   5120 x   5120  | type F16  | T+   5
# INFO:convert:[ 45/363] Writing tensor blk.4.attn_q.weight                    | size   5120 x   5120  | type F16  | T+   5
# INFO:convert:[ 46/363] Writing tensor blk.4.attn_v.weight                    | size   1280 x   5120  | type F16  | T+   5
# INFO:convert:[ 47/363] Writing tensor blk.5.attn_norm.weight                 | size   5120           | type F32  | T+   5
# INFO:convert:[ 48/363] Writing tensor blk.5.ffn_down.weight                  | size   5120 x  17920  | type F16  | T+   5
# INFO:convert:[ 49/363] Writing tensor blk.5.ffn_gate.weight                  | size  17920 x   5120  | type F16  | T+   5
# INFO:convert:[ 50/363] Writing tensor blk.5.ffn_up.weight                    | size  17920 x   5120  | type F16  | T+   5
# INFO:convert:[ 51/363] Writing tensor blk.5.ffn_norm.weight                  | size   5120           | type F32  | T+   6
# INFO:convert:[ 52/363] Writing tensor blk.5.attn_k.weight                    | size   1280 x   5120  | type F16  | T+   6
# INFO:convert:[ 53/363] Writing tensor blk.5.attn_output.weight               | size   5120 x   5120  | type F16  | T+   6
# INFO:convert:[ 54/363] Writing tensor blk.5.attn_q.weight                    | size   5120 x   5120  | type F16  | T+   6
# INFO:convert:[ 55/363] Writing tensor blk.5.attn_v.weight                    | size   1280 x   5120  | type F16  | T+   6
# INFO:convert:[ 56/363] Writing tensor blk.6.ffn_gate.weight                  | size  17920 x   5120  | type F16  | T+   6
# INFO:convert:[ 57/363] Writing tensor blk.6.ffn_up.weight                    | size  17920 x   5120  | type F16  | T+   6
# INFO:convert:[ 58/363] Writing tensor blk.6.attn_k.weight                    | size   1280 x   5120  | type F16  | T+   6
# INFO:convert:[ 59/363] Writing tensor blk.6.attn_output.weight               | size   5120 x   5120  | type F16  | T+   6
# INFO:convert:[ 60/363] Writing tensor blk.6.attn_q.weight                    | size   5120 x   5120  | type F16  | T+   6
# INFO:convert:[ 61/363] Writing tensor blk.6.attn_v.weight                    | size   1280 x   5120  | type F16  | T+   6
# INFO:convert:[ 62/363] Writing tensor blk.10.attn_norm.weight                | size   5120           | type F32  | T+   6
# INFO:convert:[ 63/363] Writing tensor blk.10.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+   6
# INFO:convert:[ 64/363] Writing tensor blk.10.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+   6
# INFO:convert:[ 65/363] Writing tensor blk.10.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+   7
# INFO:convert:[ 66/363] Writing tensor blk.10.ffn_norm.weight                 | size   5120           | type F32  | T+   7
# INFO:convert:[ 67/363] Writing tensor blk.10.attn_k.weight                   | size   1280 x   5120  | type F16  | T+   7
# INFO:convert:[ 68/363] Writing tensor blk.10.attn_output.weight              | size   5120 x   5120  | type F16  | T+   7
# INFO:convert:[ 69/363] Writing tensor blk.10.attn_q.weight                   | size   5120 x   5120  | type F16  | T+   7
# INFO:convert:[ 70/363] Writing tensor blk.10.attn_v.weight                   | size   1280 x   5120  | type F16  | T+   7
# INFO:convert:[ 71/363] Writing tensor blk.11.attn_norm.weight                | size   5120           | type F32  | T+   7
# INFO:convert:[ 72/363] Writing tensor blk.11.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+   7
# INFO:convert:[ 73/363] Writing tensor blk.11.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+   7
# INFO:convert:[ 74/363] Writing tensor blk.11.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+   7
# INFO:convert:[ 75/363] Writing tensor blk.11.ffn_norm.weight                 | size   5120           | type F32  | T+   7
# INFO:convert:[ 76/363] Writing tensor blk.11.attn_k.weight                   | size   1280 x   5120  | type F16  | T+   7
# INFO:convert:[ 77/363] Writing tensor blk.11.attn_output.weight              | size   5120 x   5120  | type F16  | T+   7
# INFO:convert:[ 78/363] Writing tensor blk.11.attn_q.weight                   | size   5120 x   5120  | type F16  | T+   7
# INFO:convert:[ 79/363] Writing tensor blk.11.attn_v.weight                   | size   1280 x   5120  | type F16  | T+   7
# INFO:convert:[ 80/363] Writing tensor blk.12.attn_norm.weight                | size   5120           | type F32  | T+   7
# INFO:convert:[ 81/363] Writing tensor blk.12.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+   7
# INFO:convert:[ 82/363] Writing tensor blk.12.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+   8
# INFO:convert:[ 83/363] Writing tensor blk.12.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+   8
# INFO:convert:[ 84/363] Writing tensor blk.12.ffn_norm.weight                 | size   5120           | type F32  | T+   8
# INFO:convert:[ 85/363] Writing tensor blk.12.attn_k.weight                   | size   1280 x   5120  | type F16  | T+   8
# INFO:convert:[ 86/363] Writing tensor blk.12.attn_output.weight              | size   5120 x   5120  | type F16  | T+   8
# INFO:convert:[ 87/363] Writing tensor blk.12.attn_q.weight                   | size   5120 x   5120  | type F16  | T+   8
# INFO:convert:[ 88/363] Writing tensor blk.12.attn_v.weight                   | size   1280 x   5120  | type F16  | T+   8
# INFO:convert:[ 89/363] Writing tensor blk.13.attn_norm.weight                | size   5120           | type F32  | T+   8
# INFO:convert:[ 90/363] Writing tensor blk.13.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+   8
# INFO:convert:[ 91/363] Writing tensor blk.13.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+   8
# INFO:convert:[ 92/363] Writing tensor blk.13.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+   8
# INFO:convert:[ 93/363] Writing tensor blk.13.ffn_norm.weight                 | size   5120           | type F32  | T+   8
# INFO:convert:[ 94/363] Writing tensor blk.13.attn_k.weight                   | size   1280 x   5120  | type F16  | T+   8
# INFO:convert:[ 95/363] Writing tensor blk.13.attn_output.weight              | size   5120 x   5120  | type F16  | T+   8
# INFO:convert:[ 96/363] Writing tensor blk.13.attn_q.weight                   | size   5120 x   5120  | type F16  | T+   9
# INFO:convert:[ 97/363] Writing tensor blk.13.attn_v.weight                   | size   1280 x   5120  | type F16  | T+   9
# INFO:convert:[ 98/363] Writing tensor blk.6.attn_norm.weight                 | size   5120           | type F32  | T+   9
# INFO:convert:[ 99/363] Writing tensor blk.6.ffn_down.weight                  | size   5120 x  17920  | type F16  | T+   9
# INFO:convert:[100/363] Writing tensor blk.6.ffn_norm.weight                  | size   5120           | type F32  | T+   9
# INFO:convert:[101/363] Writing tensor blk.7.attn_norm.weight                 | size   5120           | type F32  | T+   9
# INFO:convert:[102/363] Writing tensor blk.7.ffn_down.weight                  | size   5120 x  17920  | type F16  | T+   9
# INFO:convert:[103/363] Writing tensor blk.7.ffn_gate.weight                  | size  17920 x   5120  | type F16  | T+   9
# INFO:convert:[104/363] Writing tensor blk.7.ffn_up.weight                    | size  17920 x   5120  | type F16  | T+   9
# INFO:convert:[105/363] Writing tensor blk.7.ffn_norm.weight                  | size   5120           | type F32  | T+   9
# INFO:convert:[106/363] Writing tensor blk.7.attn_k.weight                    | size   1280 x   5120  | type F16  | T+   9
# INFO:convert:[107/363] Writing tensor blk.7.attn_output.weight               | size   5120 x   5120  | type F16  | T+   9
# INFO:convert:[108/363] Writing tensor blk.7.attn_q.weight                    | size   5120 x   5120  | type F16  | T+   9
# INFO:convert:[109/363] Writing tensor blk.7.attn_v.weight                    | size   1280 x   5120  | type F16  | T+   9
# INFO:convert:[110/363] Writing tensor blk.8.attn_norm.weight                 | size   5120           | type F32  | T+   9
# INFO:convert:[111/363] Writing tensor blk.8.ffn_down.weight                  | size   5120 x  17920  | type F16  | T+   9
# INFO:convert:[112/363] Writing tensor blk.8.ffn_gate.weight                  | size  17920 x   5120  | type F16  | T+  10
# INFO:convert:[113/363] Writing tensor blk.8.ffn_up.weight                    | size  17920 x   5120  | type F16  | T+  10
# INFO:convert:[114/363] Writing tensor blk.8.ffn_norm.weight                  | size   5120           | type F32  | T+  10
# INFO:convert:[115/363] Writing tensor blk.8.attn_k.weight                    | size   1280 x   5120  | type F16  | T+  10
# INFO:convert:[116/363] Writing tensor blk.8.attn_output.weight               | size   5120 x   5120  | type F16  | T+  10
# INFO:convert:[117/363] Writing tensor blk.8.attn_q.weight                    | size   5120 x   5120  | type F16  | T+  10
# INFO:convert:[118/363] Writing tensor blk.8.attn_v.weight                    | size   1280 x   5120  | type F16  | T+  10
# INFO:convert:[119/363] Writing tensor blk.9.attn_norm.weight                 | size   5120           | type F32  | T+  10
# INFO:convert:[120/363] Writing tensor blk.9.ffn_down.weight                  | size   5120 x  17920  | type F16  | T+  10
# INFO:convert:[121/363] Writing tensor blk.9.ffn_gate.weight                  | size  17920 x   5120  | type F16  | T+  10
# INFO:convert:[122/363] Writing tensor blk.9.ffn_up.weight                    | size  17920 x   5120  | type F16  | T+  10
# INFO:convert:[123/363] Writing tensor blk.9.ffn_norm.weight                  | size   5120           | type F32  | T+  10
# INFO:convert:[124/363] Writing tensor blk.9.attn_k.weight                    | size   1280 x   5120  | type F16  | T+  10
# INFO:convert:[125/363] Writing tensor blk.9.attn_output.weight               | size   5120 x   5120  | type F16  | T+  10
# INFO:convert:[126/363] Writing tensor blk.9.attn_q.weight                    | size   5120 x   5120  | type F16  | T+  11
# INFO:convert:[127/363] Writing tensor blk.9.attn_v.weight                    | size   1280 x   5120  | type F16  | T+  11
# INFO:convert:[128/363] Writing tensor blk.14.attn_norm.weight                | size   5120           | type F32  | T+  11
# INFO:convert:[129/363] Writing tensor blk.14.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  11
# INFO:convert:[130/363] Writing tensor blk.14.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  11
# INFO:convert:[131/363] Writing tensor blk.14.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  11
# INFO:convert:[132/363] Writing tensor blk.14.ffn_norm.weight                 | size   5120           | type F32  | T+  11
# INFO:convert:[133/363] Writing tensor blk.14.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  11
# INFO:convert:[134/363] Writing tensor blk.14.attn_output.weight              | size   5120 x   5120  | type F16  | T+  11
# INFO:convert:[135/363] Writing tensor blk.14.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  11
# INFO:convert:[136/363] Writing tensor blk.14.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  11
# INFO:convert:[137/363] Writing tensor blk.15.attn_norm.weight                | size   5120           | type F32  | T+  11
# INFO:convert:[138/363] Writing tensor blk.15.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  11
# INFO:convert:[139/363] Writing tensor blk.15.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  11
# INFO:convert:[140/363] Writing tensor blk.15.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  12
# INFO:convert:[141/363] Writing tensor blk.15.ffn_norm.weight                 | size   5120           | type F32  | T+  12
# INFO:convert:[142/363] Writing tensor blk.15.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  12
# INFO:convert:[143/363] Writing tensor blk.15.attn_output.weight              | size   5120 x   5120  | type F16  | T+  12
# INFO:convert:[144/363] Writing tensor blk.15.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  12
# INFO:convert:[145/363] Writing tensor blk.15.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  12
# INFO:convert:[146/363] Writing tensor blk.16.attn_norm.weight                | size   5120           | type F32  | T+  12
# INFO:convert:[147/363] Writing tensor blk.16.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  12
# INFO:convert:[148/363] Writing tensor blk.16.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  12
# INFO:convert:[149/363] Writing tensor blk.16.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  12
# INFO:convert:[150/363] Writing tensor blk.16.ffn_norm.weight                 | size   5120           | type F32  | T+  12
# INFO:convert:[151/363] Writing tensor blk.16.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  12
# INFO:convert:[152/363] Writing tensor blk.16.attn_output.weight              | size   5120 x   5120  | type F16  | T+  12
# INFO:convert:[153/363] Writing tensor blk.16.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  12
# INFO:convert:[154/363] Writing tensor blk.16.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  12
# INFO:convert:[155/363] Writing tensor blk.17.attn_norm.weight                | size   5120           | type F32  | T+  12
# INFO:convert:[156/363] Writing tensor blk.17.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  12
# INFO:convert:[157/363] Writing tensor blk.17.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  13
# INFO:convert:[158/363] Writing tensor blk.17.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  13
# INFO:convert:[159/363] Writing tensor blk.17.ffn_norm.weight                 | size   5120           | type F32  | T+  13
# INFO:convert:[160/363] Writing tensor blk.17.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  13
# INFO:convert:[161/363] Writing tensor blk.17.attn_output.weight              | size   5120 x   5120  | type F16  | T+  13
# INFO:convert:[162/363] Writing tensor blk.17.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  13
# INFO:convert:[163/363] Writing tensor blk.17.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  13
# INFO:convert:[164/363] Writing tensor blk.18.attn_norm.weight                | size   5120           | type F32  | T+  13
# INFO:convert:[165/363] Writing tensor blk.18.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  13
# INFO:convert:[166/363] Writing tensor blk.18.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  13
# INFO:convert:[167/363] Writing tensor blk.18.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  13
# INFO:convert:[168/363] Writing tensor blk.18.ffn_norm.weight                 | size   5120           | type F32  | T+  14
# INFO:convert:[169/363] Writing tensor blk.18.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  14
# INFO:convert:[170/363] Writing tensor blk.18.attn_output.weight              | size   5120 x   5120  | type F16  | T+  14
# INFO:convert:[171/363] Writing tensor blk.18.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  14
# INFO:convert:[172/363] Writing tensor blk.18.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  14
# INFO:convert:[173/363] Writing tensor blk.19.attn_norm.weight                | size   5120           | type F32  | T+  14
# INFO:convert:[174/363] Writing tensor blk.19.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  14
# INFO:convert:[175/363] Writing tensor blk.19.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  14
# INFO:convert:[176/363] Writing tensor blk.19.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  14
# INFO:convert:[177/363] Writing tensor blk.19.ffn_norm.weight                 | size   5120           | type F32  | T+  14
# INFO:convert:[178/363] Writing tensor blk.19.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  14
# INFO:convert:[179/363] Writing tensor blk.19.attn_output.weight              | size   5120 x   5120  | type F16  | T+  14
# INFO:convert:[180/363] Writing tensor blk.19.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  14
# INFO:convert:[181/363] Writing tensor blk.19.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  14
# INFO:convert:[182/363] Writing tensor blk.20.attn_norm.weight                | size   5120           | type F32  | T+  14
# INFO:convert:[183/363] Writing tensor blk.20.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  14
# INFO:convert:[184/363] Writing tensor blk.20.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  15
# INFO:convert:[185/363] Writing tensor blk.20.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  15
# INFO:convert:[186/363] Writing tensor blk.20.ffn_norm.weight                 | size   5120           | type F32  | T+  15
# INFO:convert:[187/363] Writing tensor blk.20.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  15
# INFO:convert:[188/363] Writing tensor blk.20.attn_output.weight              | size   5120 x   5120  | type F16  | T+  15
# INFO:convert:[189/363] Writing tensor blk.20.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  15
# INFO:convert:[190/363] Writing tensor blk.20.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  16
# INFO:convert:[191/363] Writing tensor blk.21.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  16
# INFO:convert:[192/363] Writing tensor blk.21.attn_output.weight              | size   5120 x   5120  | type F16  | T+  16
# INFO:convert:[193/363] Writing tensor blk.21.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  16
# INFO:convert:[194/363] Writing tensor blk.21.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  16
# INFO:convert:[195/363] Writing tensor blk.21.attn_norm.weight                | size   5120           | type F32  | T+  16
# INFO:convert:[196/363] Writing tensor blk.21.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  16
# INFO:convert:[197/363] Writing tensor blk.21.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  16
# INFO:convert:[198/363] Writing tensor blk.21.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  16
# INFO:convert:[199/363] Writing tensor blk.21.ffn_norm.weight                 | size   5120           | type F32  | T+  16
# INFO:convert:[200/363] Writing tensor blk.22.attn_norm.weight                | size   5120           | type F32  | T+  16
# INFO:convert:[201/363] Writing tensor blk.22.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  16
# INFO:convert:[202/363] Writing tensor blk.22.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  17
# INFO:convert:[203/363] Writing tensor blk.22.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  17
# INFO:convert:[204/363] Writing tensor blk.22.ffn_norm.weight                 | size   5120           | type F32  | T+  17
# INFO:convert:[205/363] Writing tensor blk.22.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  17
# INFO:convert:[206/363] Writing tensor blk.22.attn_output.weight              | size   5120 x   5120  | type F16  | T+  17
# INFO:convert:[207/363] Writing tensor blk.22.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  17
# INFO:convert:[208/363] Writing tensor blk.22.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  18
# INFO:convert:[209/363] Writing tensor blk.23.attn_norm.weight                | size   5120           | type F32  | T+  18
# INFO:convert:[210/363] Writing tensor blk.23.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  18
# INFO:convert:[211/363] Writing tensor blk.23.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  18
# INFO:convert:[212/363] Writing tensor blk.23.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  18
# INFO:convert:[213/363] Writing tensor blk.23.ffn_norm.weight                 | size   5120           | type F32  | T+  18
# INFO:convert:[214/363] Writing tensor blk.23.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  18
# INFO:convert:[215/363] Writing tensor blk.23.attn_output.weight              | size   5120 x   5120  | type F16  | T+  18
# INFO:convert:[216/363] Writing tensor blk.23.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  19
# INFO:convert:[217/363] Writing tensor blk.23.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  19
# INFO:convert:[218/363] Writing tensor blk.24.attn_norm.weight                | size   5120           | type F32  | T+  19
# INFO:convert:[219/363] Writing tensor blk.24.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  19
# INFO:convert:[220/363] Writing tensor blk.24.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  19
# INFO:convert:[221/363] Writing tensor blk.24.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  19
# INFO:convert:[222/363] Writing tensor blk.24.ffn_norm.weight                 | size   5120           | type F32  | T+  20
# INFO:convert:[223/363] Writing tensor blk.24.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  20
# INFO:convert:[224/363] Writing tensor blk.24.attn_output.weight              | size   5120 x   5120  | type F16  | T+  20
# INFO:convert:[225/363] Writing tensor blk.24.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  20
# INFO:convert:[226/363] Writing tensor blk.24.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  20
# INFO:convert:[227/363] Writing tensor blk.25.attn_norm.weight                | size   5120           | type F32  | T+  20
# INFO:convert:[228/363] Writing tensor blk.25.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  20
# INFO:convert:[229/363] Writing tensor blk.25.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  20
# INFO:convert:[230/363] Writing tensor blk.25.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  21
# INFO:convert:[231/363] Writing tensor blk.25.ffn_norm.weight                 | size   5120           | type F32  | T+  21
# INFO:convert:[232/363] Writing tensor blk.25.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  21
# INFO:convert:[233/363] Writing tensor blk.25.attn_output.weight              | size   5120 x   5120  | type F16  | T+  21
# INFO:convert:[234/363] Writing tensor blk.25.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  22
# INFO:convert:[235/363] Writing tensor blk.25.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  22
# INFO:convert:[236/363] Writing tensor blk.26.attn_norm.weight                | size   5120           | type F32  | T+  22
# INFO:convert:[237/363] Writing tensor blk.26.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  22
# INFO:convert:[238/363] Writing tensor blk.26.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  22
# INFO:convert:[239/363] Writing tensor blk.26.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  23
# INFO:convert:[240/363] Writing tensor blk.26.ffn_norm.weight                 | size   5120           | type F32  | T+  23
# INFO:convert:[241/363] Writing tensor blk.26.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  23
# INFO:convert:[242/363] Writing tensor blk.26.attn_output.weight              | size   5120 x   5120  | type F16  | T+  23
# INFO:convert:[243/363] Writing tensor blk.26.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  24
# INFO:convert:[244/363] Writing tensor blk.26.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  24
# INFO:convert:[245/363] Writing tensor blk.27.attn_norm.weight                | size   5120           | type F32  | T+  24
# INFO:convert:[246/363] Writing tensor blk.27.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  24
# INFO:convert:[247/363] Writing tensor blk.27.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  24
# INFO:convert:[248/363] Writing tensor blk.27.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  25
# INFO:convert:[249/363] Writing tensor blk.27.ffn_norm.weight                 | size   5120           | type F32  | T+  25
# INFO:convert:[250/363] Writing tensor blk.27.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  25
# INFO:convert:[251/363] Writing tensor blk.27.attn_output.weight              | size   5120 x   5120  | type F16  | T+  25
# INFO:convert:[252/363] Writing tensor blk.27.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  26
# INFO:convert:[253/363] Writing tensor blk.27.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  26
# INFO:convert:[254/363] Writing tensor blk.28.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  26
# INFO:convert:[255/363] Writing tensor blk.28.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  26
# INFO:convert:[256/363] Writing tensor blk.28.attn_output.weight              | size   5120 x   5120  | type F16  | T+  26
# INFO:convert:[257/363] Writing tensor blk.28.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  26
# INFO:convert:[258/363] Writing tensor blk.28.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  27
# INFO:convert:[259/363] Writing tensor blk.28.attn_norm.weight                | size   5120           | type F32  | T+  27
# INFO:convert:[260/363] Writing tensor blk.28.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  27
# INFO:convert:[261/363] Writing tensor blk.28.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  27
# INFO:convert:[262/363] Writing tensor blk.28.ffn_norm.weight                 | size   5120           | type F32  | T+  28
# INFO:convert:[263/363] Writing tensor blk.29.attn_norm.weight                | size   5120           | type F32  | T+  28
# INFO:convert:[264/363] Writing tensor blk.29.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  28
# INFO:convert:[265/363] Writing tensor blk.29.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  28
# INFO:convert:[266/363] Writing tensor blk.29.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  29
# INFO:convert:[267/363] Writing tensor blk.29.ffn_norm.weight                 | size   5120           | type F32  | T+  29
# INFO:convert:[268/363] Writing tensor blk.29.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  29
# INFO:convert:[269/363] Writing tensor blk.29.attn_output.weight              | size   5120 x   5120  | type F16  | T+  29
# INFO:convert:[270/363] Writing tensor blk.29.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  29
# INFO:convert:[271/363] Writing tensor blk.29.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  30
# INFO:convert:[272/363] Writing tensor blk.30.attn_norm.weight                | size   5120           | type F32  | T+  30
# INFO:convert:[273/363] Writing tensor blk.30.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  30
# INFO:convert:[274/363] Writing tensor blk.30.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  30
# INFO:convert:[275/363] Writing tensor blk.30.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  31
# INFO:convert:[276/363] Writing tensor blk.30.ffn_norm.weight                 | size   5120           | type F32  | T+  31
# INFO:convert:[277/363] Writing tensor blk.30.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  31
# INFO:convert:[278/363] Writing tensor blk.30.attn_output.weight              | size   5120 x   5120  | type F16  | T+  31
# INFO:convert:[279/363] Writing tensor blk.30.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  32
# INFO:convert:[280/363] Writing tensor blk.30.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  32
# INFO:convert:[281/363] Writing tensor blk.31.attn_norm.weight                | size   5120           | type F32  | T+  32
# INFO:convert:[282/363] Writing tensor blk.31.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  32
# INFO:convert:[283/363] Writing tensor blk.31.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  32
# INFO:convert:[284/363] Writing tensor blk.31.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  33
# INFO:convert:[285/363] Writing tensor blk.31.ffn_norm.weight                 | size   5120           | type F32  | T+  33
# INFO:convert:[286/363] Writing tensor blk.31.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  33
# INFO:convert:[287/363] Writing tensor blk.31.attn_output.weight              | size   5120 x   5120  | type F16  | T+  33
# INFO:convert:[288/363] Writing tensor blk.31.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  34
# INFO:convert:[289/363] Writing tensor blk.31.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  34
# INFO:convert:[290/363] Writing tensor blk.32.attn_norm.weight                | size   5120           | type F32  | T+  34
# INFO:convert:[291/363] Writing tensor blk.32.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  34
# INFO:convert:[292/363] Writing tensor blk.32.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  35
# INFO:convert:[293/363] Writing tensor blk.32.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  36
# INFO:convert:[294/363] Writing tensor blk.32.ffn_norm.weight                 | size   5120           | type F32  | T+  36
# INFO:convert:[295/363] Writing tensor blk.32.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  36
# INFO:convert:[296/363] Writing tensor blk.32.attn_output.weight              | size   5120 x   5120  | type F16  | T+  36
# INFO:convert:[297/363] Writing tensor blk.32.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  37
# INFO:convert:[298/363] Writing tensor blk.32.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  37
# INFO:convert:[299/363] Writing tensor blk.33.attn_norm.weight                | size   5120           | type F32  | T+  37
# INFO:convert:[300/363] Writing tensor blk.33.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  37
# INFO:convert:[301/363] Writing tensor blk.33.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  38
# INFO:convert:[302/363] Writing tensor blk.33.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  39
# INFO:convert:[303/363] Writing tensor blk.33.ffn_norm.weight                 | size   5120           | type F32  | T+  39
# INFO:convert:[304/363] Writing tensor blk.33.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  39
# INFO:convert:[305/363] Writing tensor blk.33.attn_output.weight              | size   5120 x   5120  | type F16  | T+  40
# INFO:convert:[306/363] Writing tensor blk.33.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  40
# INFO:convert:[307/363] Writing tensor blk.33.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  40
# INFO:convert:[308/363] Writing tensor blk.34.attn_norm.weight                | size   5120           | type F32  | T+  40
# INFO:convert:[309/363] Writing tensor blk.34.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  40
# INFO:convert:[310/363] Writing tensor blk.34.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  41
# INFO:convert:[311/363] Writing tensor blk.34.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  42
# INFO:convert:[312/363] Writing tensor blk.34.ffn_norm.weight                 | size   5120           | type F32  | T+  42
# INFO:convert:[313/363] Writing tensor blk.34.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  42
# INFO:convert:[314/363] Writing tensor blk.34.attn_output.weight              | size   5120 x   5120  | type F16  | T+  42
# INFO:convert:[315/363] Writing tensor blk.34.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  42
# INFO:convert:[316/363] Writing tensor blk.34.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  42
# INFO:convert:[317/363] Writing tensor blk.35.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  43
# INFO:convert:[318/363] Writing tensor blk.35.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  43
# INFO:convert:[319/363] Writing tensor blk.35.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  44
# INFO:convert:[320/363] Writing tensor blk.35.attn_output.weight              | size   5120 x   5120  | type F16  | T+  44
# INFO:convert:[321/363] Writing tensor blk.35.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  44
# INFO:convert:[322/363] Writing tensor blk.35.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  44
# INFO:convert:[323/363] Writing tensor output.weight                          | size  32064 x   5120  | type F16  | T+  44
# INFO:convert:[324/363] Writing tensor blk.35.attn_norm.weight                | size   5120           | type F32  | T+  46
# INFO:convert:[325/363] Writing tensor blk.35.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  46
# INFO:convert:[326/363] Writing tensor blk.35.ffn_norm.weight                 | size   5120           | type F32  | T+  46
# INFO:convert:[327/363] Writing tensor blk.36.attn_norm.weight                | size   5120           | type F32  | T+  46
# INFO:convert:[328/363] Writing tensor blk.36.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  46
# INFO:convert:[329/363] Writing tensor blk.36.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  47
# INFO:convert:[330/363] Writing tensor blk.36.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  48
# INFO:convert:[331/363] Writing tensor blk.36.ffn_norm.weight                 | size   5120           | type F32  | T+  48
# INFO:convert:[332/363] Writing tensor blk.36.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  48
# INFO:convert:[333/363] Writing tensor blk.36.attn_output.weight              | size   5120 x   5120  | type F16  | T+  48
# INFO:convert:[334/363] Writing tensor blk.36.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  49
# INFO:convert:[335/363] Writing tensor blk.36.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  49
# INFO:convert:[336/363] Writing tensor blk.37.attn_norm.weight                | size   5120           | type F32  | T+  49
# INFO:convert:[337/363] Writing tensor blk.37.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  49
# INFO:convert:[338/363] Writing tensor blk.37.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  49
# INFO:convert:[339/363] Writing tensor blk.37.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  50
# INFO:convert:[340/363] Writing tensor blk.37.ffn_norm.weight                 | size   5120           | type F32  | T+  51
# INFO:convert:[341/363] Writing tensor blk.37.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  51
# INFO:convert:[342/363] Writing tensor blk.37.attn_output.weight              | size   5120 x   5120  | type F16  | T+  51
# INFO:convert:[343/363] Writing tensor blk.37.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  51
# INFO:convert:[344/363] Writing tensor blk.37.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  51
# INFO:convert:[345/363] Writing tensor blk.38.attn_norm.weight                | size   5120           | type F32  | T+  51
# INFO:convert:[346/363] Writing tensor blk.38.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  51
# INFO:convert:[347/363] Writing tensor blk.38.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  52
# INFO:convert:[348/363] Writing tensor blk.38.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  53
# INFO:convert:[349/363] Writing tensor blk.38.ffn_norm.weight                 | size   5120           | type F32  | T+  53
# INFO:convert:[350/363] Writing tensor blk.38.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  53
# INFO:convert:[351/363] Writing tensor blk.38.attn_output.weight              | size   5120 x   5120  | type F16  | T+  53
# INFO:convert:[352/363] Writing tensor blk.38.attn_q.weight                   | size   5120 x   5120  | type F16  | T+  53
# INFO:convert:[353/363] Writing tensor blk.38.attn_v.weight                   | size   1280 x   5120  | type F16  | T+  54
# INFO:convert:[354/363] Writing tensor blk.39.attn_norm.weight                | size   5120           | type F32  | T+  54
# INFO:convert:[355/363] Writing tensor blk.39.ffn_down.weight                 | size   5120 x  17920  | type F16  | T+  54
# INFO:convert:[356/363] Writing tensor blk.39.ffn_gate.weight                 | size  17920 x   5120  | type F16  | T+  54
# INFO:convert:[357/363] Writing tensor blk.39.ffn_up.weight                   | size  17920 x   5120  | type F16  | T+  55
# INFO:convert:[358/363] Writing tensor blk.39.ffn_norm.weight                 | size   5120           | type F32  | T+  55
# INFO:convert:[359/363] Writing tensor blk.39.attn_k.weight                   | size   1280 x   5120  | type F16  | T+  55
# INFO:convert:[360/363] Writing tensor blk.39.attn_output.weight              | size   5120 x   5120  | type F16  | T+  55
# ...
# [ 261/ 363]                 blk.28.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 262/ 363]               blk.28.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 263/ 363]              blk.29.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 264/ 363]               blk.29.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 265/ 363]               blk.29.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 266/ 363]                 blk.29.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 267/ 363]               blk.29.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 268/ 363]                 blk.29.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 269/ 363]            blk.29.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 270/ 363]                 blk.29.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 271/ 363]                 blk.29.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 272/ 363]              blk.30.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 273/ 363]               blk.30.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 274/ 363]               blk.30.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 275/ 363]                 blk.30.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 276/ 363]               blk.30.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 277/ 363]                 blk.30.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 278/ 363]            blk.30.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 279/ 363]                 blk.30.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 280/ 363]                 blk.30.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 281/ 363]              blk.31.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 282/ 363]               blk.31.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q6_K .. size =   175.00 MiB ->    71.78 MiB
# [ 283/ 363]               blk.31.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 284/ 363]                 blk.31.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 285/ 363]               blk.31.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 286/ 363]                 blk.31.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 287/ 363]            blk.31.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 288/ 363]                 blk.31.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 289/ 363]                 blk.31.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q6_K .. size =    12.50 MiB ->     5.13 MiB
# [ 290/ 363]              blk.32.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 291/ 363]               blk.32.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 292/ 363]               blk.32.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 293/ 363]                 blk.32.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 294/ 363]               blk.32.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 295/ 363]                 blk.32.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 296/ 363]            blk.32.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 297/ 363]                 blk.32.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 298/ 363]                 blk.32.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 299/ 363]              blk.33.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 300/ 363]               blk.33.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 301/ 363]               blk.33.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 302/ 363]                 blk.33.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 303/ 363]               blk.33.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 304/ 363]                 blk.33.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 305/ 363]            blk.33.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 306/ 363]                 blk.33.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 307/ 363]                 blk.33.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 308/ 363]              blk.34.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 309/ 363]               blk.34.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q6_K .. size =   175.00 MiB ->    71.78 MiB
# [ 310/ 363]               blk.34.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 311/ 363]                 blk.34.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 312/ 363]               blk.34.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 313/ 363]                 blk.34.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 314/ 363]            blk.34.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 315/ 363]                 blk.34.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 316/ 363]                 blk.34.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q6_K .. size =    12.50 MiB ->     5.13 MiB
# [ 317/ 363]               blk.35.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 318/ 363]                 blk.35.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 319/ 363]                 blk.35.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 320/ 363]            blk.35.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 321/ 363]                 blk.35.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 322/ 363]                 blk.35.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q6_K .. size =    12.50 MiB ->     5.13 MiB
# [ 323/ 363]                        output.weight - [ 5120, 32064,     1,     1], type =    f16, converting to q6_K .. size =   313.12 MiB ->   128.43 MiB
# [ 324/ 363]              blk.35.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 325/ 363]               blk.35.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q6_K .. size =   175.00 MiB ->    71.78 MiB
# [ 326/ 363]               blk.35.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 327/ 363]              blk.36.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 328/ 363]               blk.36.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q6_K .. size =   175.00 MiB ->    71.78 MiB
# [ 329/ 363]               blk.36.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 330/ 363]                 blk.36.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 331/ 363]               blk.36.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 332/ 363]                 blk.36.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 333/ 363]            blk.36.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 334/ 363]                 blk.36.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 335/ 363]                 blk.36.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q6_K .. size =    12.50 MiB ->     5.13 MiB
# [ 336/ 363]              blk.37.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 337/ 363]               blk.37.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q6_K .. size =   175.00 MiB ->    71.78 MiB
# [ 338/ 363]               blk.37.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 339/ 363]                 blk.37.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 340/ 363]               blk.37.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 341/ 363]                 blk.37.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 342/ 363]            blk.37.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 343/ 363]                 blk.37.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 344/ 363]                 blk.37.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q6_K .. size =    12.50 MiB ->     5.13 MiB
# [ 345/ 363]              blk.38.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 346/ 363]               blk.38.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q6_K .. size =   175.00 MiB ->    71.78 MiB
# [ 347/ 363]               blk.38.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 348/ 363]                 blk.38.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 349/ 363]               blk.38.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 350/ 363]                 blk.38.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 351/ 363]            blk.38.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 352/ 363]                 blk.38.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 353/ 363]                 blk.38.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q6_K .. size =    12.50 MiB ->     5.13 MiB
# [ 354/ 363]              blk.39.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 355/ 363]               blk.39.ffn_down.weight - [17920,  5120,     1,     1], type =    f16, converting to q6_K .. size =   175.00 MiB ->    71.78 MiB
# [ 356/ 363]               blk.39.ffn_gate.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 357/ 363]                 blk.39.ffn_up.weight - [ 5120, 17920,     1,     1], type =    f16, converting to q5_K .. size =   175.00 MiB ->    60.16 MiB
# [ 358/ 363]               blk.39.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 359/ 363]                 blk.39.attn_k.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q5_K .. size =    12.50 MiB ->     4.30 MiB
# [ 360/ 363]            blk.39.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 361/ 363]                 blk.39.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, converting to q5_K .. size =    50.00 MiB ->    17.19 MiB
# [ 362/ 363]                 blk.39.attn_v.weight - [ 5120,  1280,     1,     1], type =    f16, converting to q6_K .. size =    12.50 MiB ->     5.13 MiB
# [ 363/ 363]                   output_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# llama_model_quantize_internal: model size  = 26627.83 MB
# llama_model_quantize_internal: quant size  =  9424.17 MB
#
# main: quantize time = 103088.99 ms
# main:    total time = 103088.99 ms
# Unsloth: Conversion completed! Output location: ./felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m-unsloth.Q5_K_M.gguf
# Unsloth: Uploading GGUF to Huggingface Hub...
# Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m-unsloth.Q5_K_M.gguf:   0%|          | 0.00/…
# Saved GGUF to https://huggingface.co/felixml/Phi-3-medium-4k-instruct-synthetic_text_to_sql-lora-3epochs-q5_k_m
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in `llama.cpp` or a UI based system like `GPT4All`. You can install GPT4All by going [here](https://gpt4all.io/index.html).

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Zephyr DPO 2x faster [free Colab](https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing)
# 2. Llama 7b 2x faster [free Colab](https://colab.research.google.com/drive/1lBzz5KeZJKXjvivbYvmGarix9Ao6Wxe5?usp=sharing)
# 3. TinyLlama 4x faster full Alpaca 52K in 1 hour [free Colab](https://colab.research.google.com/drive/1AZghoNBQaMDgWJpi4RbffGM1h6raLUj9?usp=sharing)
# 4. CodeLlama 34b 2x faster [A100 on Colab](https://colab.research.google.com/drive/1y7A0AxE3y8gdj4AVkl2aZX47Xu3P1wJT?usp=sharing)
# 5. Mistral 7b [free Kaggle version](https://www.kaggle.com/code/danielhanchen/kaggle-mistral-7b-unsloth-notebook)
# 6. We also did a [blog](https://huggingface.co/blog/unsloth-trl) with 🤗 HuggingFace, and we're in the TRL [docs](https://huggingface.co/docs/trl/main/en/sft_trainer#accelerate-fine-tuning-2x-using-unsloth)!
# 7. Text completions like novel writing [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing)
# 9. Gemma 6 trillion tokens is 2.5x faster! [free Colab](https://colab.research.google.com/drive/10NbwlsRChbma1v55m8LAPYG15uQv6HLo?usp=sharing)
#
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Support our work if you can! Thanks!
# </div>
